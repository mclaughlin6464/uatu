# %%
from uatu.watchers import *
from sklearn.model_selection import train_test_split

# %%
X,Y = get_xy_from_dir('../data/Box001/', 1)

# %% [raw]
# # X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.7)
# train_dset = Dataset(X_train, Y_train, 20, shuffle = True, augment = True)
# test_dset = Dataset(X_test, Y_test, 20, shuffle = True, augment = True)
# data = (train_dset, test_dset, None)

# %%
train_dset = Dataset(X[:11], Y[:11], 4, shuffle = True, augment = True)
test_dset = Dataset(X[11:13], Y[11:13], 2, shuffle = True, augment = True)

data = (train_dset, test_dset, None)

# %%
device = 'CPU:0'

# %%
X.shape
# Out:
# (64, 64, 64, 64, 1)

# %%
np.unique(X)
# Out:
# array([   0,    1,    2, ..., 8424, 8931, 9962])

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
from matplotlib.colors import LogNorm

# %%
X[X==0] = 1+1e-6

# %%
for i in xrange(64):
    print Y[0]
    plt.imshow(X[0, i, :, :, 0], norm=LogNorm())
    
    plt.show()
# Out:
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# [0.319703 0.912933]
# ...

# %% [raw]
# train(standard_convnet_init_fn, standard_optimizer_init_fn,data, device, fname = 'tmp', print_every = 1)
