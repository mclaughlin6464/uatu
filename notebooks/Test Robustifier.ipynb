# %% [markdown]
# Want to see what the deal is with the robust maps.

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
#sns.set()

# %%
import numpy as np
import h5py

# %%
path = '/home/sean/Git/uatu/data/UatuLightconeTrainingRobustRestnet.hdf5'

# %%
f = h5py.File(path, 'r')

# %%
X = f['Box000']['X'][0]

# %%
plt.imshow(X)

# %%
f.close()
