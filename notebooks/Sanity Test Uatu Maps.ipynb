# %% [markdown]
# Want to make sure my preliminary Kappa maps look ok

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns

# %%
import numpy as np
from scipy.ndimage import gaussian_filter

# %%
path = '/scratch/users/swmclau2/UatuFastpmTest2/Box%03d/lightcone/1/proj_map_%03d.npy'

# %%
k = np.load(path%(1,1))

# %%
k = k-k.min()+1e-6

# %%
smooth = 4
for i in k[:10]:
    li = gaussian_filter(i + np.random.randn(*i.shape)*1e-4, smooth)
    plt.imshow(li)
    plt.show();
