# %% [markdown]
# The networks are giving weird answers for the normal test set than the "attacked" ones. I'm trying to see if I can find out why.

# %%
import h5py
from os import path
# Out:
# /home/users/swmclau2/.local/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
#import seaborn as sns
#sns.set()

# %%
test_dir = '/oak/stanford/orgs/kipac/users/swmclau2/Uatu/UatuLightconeTraining/'
orig_test_maps_fname = 'UatuLightconeTraining.hdf5'
attacked_test_maps_fname = 'UatuLightconeAttackedShuffled_v2.hdf5'

# %%
f1 = h5py.File(path.join(test_dir, orig_test_maps_fname), 'r')
f2 = h5py.File(path.join(test_dir, attacked_test_maps_fname), 'r')

# %%
idx = 124

# %%
x1 = f1['Box000']['X'][idx].squeeze()

# %%
x2 = f2['Box000']['X'][idx].squeeze()

# %%
x1.mean(), x1.std()
# Out:
# (6.777645466896625, 0.261615242544918)

# %%
x2.mean(), x2.std()
# Out:
# (0.14509982008953826, 0.005686749400034403)

# %%
im = plt.imshow(x1);
plt.colorbar(im);

# %%
im = plt.imshow(x2);
plt.colorbar(im)
